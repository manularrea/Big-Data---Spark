# %% [markdown]
# # RDD - Actions

# %% [markdown]
# ## Setup Spark environment

# %%
from pathlib import Path

installation_folder = Path("/content/spark-3.5.0-bin-hadoop3")

if not installation_folder.exists():

  # Install Java locally
  # !apt-get install openjdk-8-jdk-headless -qq > /dev/null

  # Download & decompress Spark
  # !wget -q https://dlcdn.apache.org/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz -O spark-3.5.0-bin-hadoop3.tgz
  # !tar xf spark-3.5.0-bin-hadoop3.tgz

  # Install finspark
  # !pip install -q findspark

  # Setup required environment variables
  import os
  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
  os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"

  print("Spark setup finished!")

else:
  print("Skipping Spark setup")
# Out:
# Spark setup finished!

# %% [markdown]
# ## Prepare the Spark context

# %%
# Import findpsark
import findspark

# Configure the environment
findspark.init()

# Import the Spark components required for the context creation
from pyspark import SparkConf, SparkContext

# Configure and create the context
conf = SparkConf()
conf = conf.setAppName('mds-session')
conf = conf.setMaster('local[32]')
sc = SparkContext.getOrCreate(conf=conf)

# %% [markdown]
# ## reduce

# %%
rdd1 = sc.parallelize([('a', 1), ('b', 2), ('c', 3)])
rdd1.reduce(lambda el1, el2: len(el2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-25392d627b77> in <cell line: 2>()
#       1 rdd1 = sc.parallelize([('a', 1), ('b', 2), ('c', 3)])
# ----> 2 rdd1.reduce(lambda el1, el2: len(el2))
#
# /content/spark-3.5.0-bin-hadoop3/python/pyspark/rdd.py in reduce(self, f)
#    1924         vals = self.mapPartitions(func).collect()
#    1925         if vals:
# -> 1926             return reduce(f, vals)
#    1927         raise ValueError("Can not reduce() empty RDD")
#    1928
#
# /content/spark-3.5.0-bin-hadoop3/python/pyspark/util.py in wrapper(*args, **kwargs)
#      81     def wrapper(*args: Any, **kwargs: Any) -> Any:
#      82         try:
# ---> 83             return f(*args, **kwargs)
#      84         except StopIteration as exc:
#      85             raise PySparkRuntimeError(
#
# <ipython-input-5-25392d627b77> in <lambda>(el1, el2)
#       1 rdd1 = sc.parallelize([('a', 1), ('b', 2), ('c', 3)])
# ----> 2 rdd1.reduce(lambda el1, el2: len(el2))
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# ## count, max, min, sum, mean, stdev, variance

# %%
# Actions: count, max, min, sum, mean, stdev, variance
rdd1 = sc.parallelize(list(range(100)))

# %%
rdd1.count()
# Out:
# 100

# %%
rdd1.max()
# Out:
# 99

# %%
rdd1.min()
# Out:
# 0

# %%
rdd1.sum()
# Out:
# 4950

# %%
rdd1.mean()
# Out:
# 49.5

# %%
rdd1.stdev()
# Out:
# 28.86607004772212

# %%
rdd1.variance()
# Out:
# 833.25

# %% [markdown]
# ## collect, take, first

# %%
rdd1 = sc.parallelize([('a', 1), ('c', 10), ('b', 2)])

# %%
type(rdd1)
# Out:
# pyspark.rdd.RDD

# %%
rdd1.take(1)
# Out:
# [('a', 1)]

# %%
rdd1.first()
# Out:
# ('a', 1)

# %% [markdown]
# ## saveAsTextFile

# %%
# Actions: saveAsTextFile
rdd1 = sc.parallelize(range(100))
rdd1.saveAsTextFile('/content/output1')

# %% [markdown]
# ## Close the Spark context

# %%
sc.stop()
